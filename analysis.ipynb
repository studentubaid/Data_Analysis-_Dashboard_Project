# %%
import pandas as pd
import charts   # import your charts.py file

# Load dataset
player = pd.read_csv("C:/Users/Dell/Documents/dashboard_project/data/historical_RAPTOR_by_player.csv")

# 1. Pie Chart → possessions
charts.pi_chart(player)

# 2. Histogram → raptor_total values
charts.histo_chart(player["raptor_total"])

# 3. Line Chart → war_total over seasons
charts.line_chart(player["season"], player["war_total"])

# 4. Bar Chart → war_total top players
charts.bar_chart(player)

# 5. Scatter Plot → offense vs defense
charts.scatter_chart(player["raptor_offense"], player["raptor_defense"])

# 6. Box Plot → minutes played
charts.box_chart(player["mp"])

# 7. Heatmap → correlations
charts.heatmap_chart(player.select_dtypes(include='number'))

# 8. Area Chart → cumulative war_total
charts.area_chart(player)

# 9. Count Plot → players per season
charts.count_chart(player)

# 10. Violin Plot → war_total distribution
charts.violin_chart(player)
